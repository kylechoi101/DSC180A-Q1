# %% [markdown]
# ### Datasets

# %%
import pandas as pd

# %%
inflow = pd.read_parquet('/uss/hdsi-prismdata/q1-ucsd-inflows.pqt')
outflow = pd.read_parquet('/uss/hdsi-prismdata/q1-ucsd-outflows.pqt')

# %%
inflow.sample(5)
# Out:
#         prism_consumer_id prism_account_id               memo  amount  \
# 267653               3115         acc_6698  EXTERNAL_TRANSFER  200.00
# 414687               4817         acc_8400  EXTERNAL_TRANSFER  175.00
# 148695               1569         acc_4345      SELF_TRANSFER  100.00
# 327190               3844         acc_7427  EXTERNAL_TRANSFER   73.69
# 241096               2760         acc_6343  EXTERNAL_TRANSFER  825.63
#
#        posted_date           category
# 267653  2022-06-14  EXTERNAL_TRANSFER
# 414687  2021-07-20  EXTERNAL_TRANSFER
# 148695  2022-04-29      SELF_TRANSFER
# 327190  2022-10-21  EXTERNAL_TRANSFER
# 241096  2022-06-29  EXTERNAL_TRANSFER

# %%
outflow.sample(5)
# Out:
#          prism_consumer_id prism_account_id  \
# 609852                1304         acc_3648
# 2301857               5401         acc_8984
# 421180                 920         acc_2638
# 1149327               2743         acc_6326
# 500920                1089         acc_3081
#
#                                                       memo  amount  \
# 609852                                         Chick-fil-A   15.58
# 2301857  CHECKCARD XXXX TARGET.COM * XXX-XXX-XXXX MN XX...    9.77
# 421180                                   EXTERNAL_TRANSFER    5.00
# 1149327  CHECKCARD XXXX KLOVER APP BOOST Chicago IL XXX...   10.00
# 500920   CHECKCARD XXXX CHOWKING VALLEJO VALLEJO CA XXX...   23.34
#
#         posted_date             category
# 609852   2020-12-02   FOOD_AND_BEVERAGES
# 2301857  2021-12-01            GROCERIES
# 421180   2023-03-29    EXTERNAL_TRANSFER
# 1149327  2022-10-27  GENERAL_MERCHANDISE
# 500920   2022-11-14   FOOD_AND_BEVERAGES

# %% [markdown]
# # What are the most common merchants per category? [pick 5-10 categories]

# %% [markdown]
# ### Looking at the dataframes above, it seems that merchant data is stored in the memo column. But before digging into the merchants, we will browse through the categories.

# %%
inflow['category'].value_counts()
# Out:
# category
# EXTERNAL_TRANSFER        156533
# SELF_TRANSFER            110437
# DEPOSIT                   61345
# MISCELLANEOUS             55648
# PAYCHECK                  33138
# PAYCHECK_PLACEHOLDER      26087
# REFUND                    23220
# INVESTMENT_INCOME         17325
# SMALL_DOLLAR_ADVANCE      13621
# OTHER_BENEFITS             7708
# TAX                        3405
# LOAN                       2513
# UNEMPLOYMENT_BENEFITS      1961
# INSURANCE                   174
# Name: count, dtype: int64

# %%
outflow['category'].value_counts()
# Out:
# category
# GENERAL_MERCHANDISE    524063
# FOOD_AND_BEVERAGES     481994
# EXTERNAL_TRANSFER      320998
# GROCERIES              219331
# AUTOMOTIVE             208579
# ATM_CASH               117651
# UNCATEGORIZED          117409
# LOAN                    90945
# ENTERTAINMENT           80885
# ESSENTIAL_SERVICES      77137
# CREDIT_CARD_PAYMENT     75506
# SELF_TRANSFER           73281
# TRAVEL                  59647
# HEALTHCARE_MEDICAL      40842
# ACCOUNT_FEES            37511
# INSURANCE               30244
# PETS                     9266
# HOME_IMPROVEMENT         8600
# GIFTS_DONATIONS          4719
# EDUCATION                4499
# OVERDRAFT                3386
# TAX                      3186
# RENT                     3147
# BNPL                     1543
# MORTGAGE                 1119
# PAYCHECK                 1040
# CHILD_DEPENDENTS          936
# BILLS_UTILITIES            23
# AUTO_LOAN                   1
# Name: count, dtype: int64

# %% [markdown]
# ### Let's look through each category and see what merchants there are.

# %%
inflow[inflow['category'] == 'EXTERNAL_TRANSFER']['memo'].value_counts()
# Out:
# memo
# EXTERNAL_TRANSFER    156533
# Name: count, dtype: int64

# %%
inflow[inflow['category'] == 'SELF_TRANSFER']['memo'].value_counts()
# Out:
# memo
# SELF_TRANSFER    110437
# Name: count, dtype: int64

# %%
inflow['memo'].value_counts()
# Out:
# memo
# EXTERNAL_TRANSFER        156533
# SELF_TRANSFER            110437
# DEPOSIT                   61345
# MISCELLANEOUS             55648
# PAYCHECK                  33138
# PAYCHECK_PLACEHOLDER      26087
# REFUND                    23220
# INVESTMENT_INCOME         17325
# SMALL_DOLLAR_ADVANCE      13621
# OTHER_BENEFITS             7708
# TAX                        3405
# LOAN                       2513
# UNEMPLOYMENT_BENEFITS      1961
# INSURANCE                   174
# Name: count, dtype: int64

# %% [markdown]
# ### It seems that there are no merchant information in the inflow df.

# %%
outflow['memo'].value_counts()
# Out:
# memo
# EXTERNAL_TRANSFER                                                                    320998
# AUTOMOTIVE                                                                           208579
# ATM_CASH                                                                             117651
# UNCATEGORIZED                                                                        117409
# LOAN                                                                                  90945
#                                                                                       ...
# Par Gators Dockside -                                                                     1
# Chilis Mandarin                                                                           1
# Chilis Bay Meadows                                                                        1
# Southside Liquor                                                                          1
# POS WITHDRAWALWAL-MART #XXXX XXXX E MCKELLIPS RD MESA AZ  Card 15 #XXXX  MCC XXXX         1
# Name: count, Length: 528786, dtype: int64

# %% [markdown]
# ### There are in outflow so let's explore more.

# %%
outflow[outflow['category'] == 'GENERAL_MERCHANDISE']['memo'].value_counts()
# Out:
# memo
# Amazon                                                                                                                           31725
# 7-Eleven                                                                                                                         11675
# Circle K                                                                                                                         10148
# Dollar General                                                                                                                    7872
# Apple                                                                                                                             7394
#                                                                                                                                  ...
# PURCHASE 06-17 FLEXSHOPPER , FL VNT XXXX                                                                                             1
# PURCHASE 08-10 PLAYSTATIO FOSTER CITY, CA STR XXXX                                                                                   1
# PURCHASE 09-21 FLEXSHOPPER ECOMMERCE , FL VNT XXXX                                                                                   1
# PURCHASE 09-03 HELP.HBOMAX.COM HTTPSHBOMAX.C, NY VNT XXXX                                                                            1
# DEBIT CARD WITHDRAWAL PURCHASEAmazon Prime*TI40L27R3 Amzn.com/bill WA Date 01/16/23 PURCH XXXXXXXXXXXXXXXXXXXXXX  Card 15 #34        1
# Name: count, Length: 217779, dtype: int64

# %%
outflow[outflow['category'] == 'CHILD_DEPENDENTS']['memo'].value_counts()
# Out:
# memo
# CHILD_DEPENDENTS    936
# Name: count, dtype: int64

# %% [markdown]
# ### Some categories had a large variety of merchants while others had none/few as seen above. We continued looking at each category and chose the following ones to work with because they have a wider range of merchant variety.

# %%
chosen_cats = ['GENERAL_MERCHANDISE', 'FOOD_AND_BEVERAGES', 'GROCERIES', 'TRAVEL', 'PETS', 'RENT']

# %% [markdown]
# ### Let's see a few examples of the top 10 merchants.

# %%
outflow[outflow['category']=='FOOD_AND_BEVERAGES']['memo'].value_counts()[:10]
# Out:
# memo
# McDonald's                22670
# Starbucks                 12777
# Chick-fil-A                7933
# Taco Bell                  6071
# Wendy's                    4694
# Burger King                4282
# Dunkin' Donuts             4265
# McDonald''s                3875
# Sonic                      2925
# Chipotle Mexican Grill     2679
# Name: count, dtype: int64

# %%
outflow[outflow['category']=='GENERAL_MERCHANDISE']['memo'].value_counts()[:10]
# Out:
# memo
# Amazon            31725
# 7-Eleven          11675
# Circle K          10148
# Dollar General     7872
# Apple              7394
# Home Depot         7213
# Costco             4760
# Google             4567
# APPLE.COM/BILL     3270
# Amazon Prime       3159
# Name: count, dtype: int64

# %% [markdown]
# ### Let's do the same for the rest of the chosen categories.

# %%
merchant_df = pd.DataFrame()
for i in chosen_cats:
    memo_df = pd.DataFrame({'Category': i,'Count': outflow[outflow['category']==i]['memo'].value_counts()[:10]})
    memo_df.index.rename('Merchant', inplace=True)
    memo_df = memo_df.reset_index()
    merchant_df = pd.concat([merchant_df, memo_df], axis=0)
    merchant_df = merchant_df[['Category', 'Merchant', 'Count']]

merchant_df
# Out:
#               Category                                           Merchant  \
# 0  GENERAL_MERCHANDISE                                             Amazon
# 1  GENERAL_MERCHANDISE                                           7-Eleven
# 2  GENERAL_MERCHANDISE                                           Circle K
# 3  GENERAL_MERCHANDISE                                     Dollar General
# 4  GENERAL_MERCHANDISE                                              Apple
# 5  GENERAL_MERCHANDISE                                         Home Depot
# 6  GENERAL_MERCHANDISE                                             Costco
# 7  GENERAL_MERCHANDISE                                             Google
# 8  GENERAL_MERCHANDISE                                     APPLE.COM/BILL
# 9  GENERAL_MERCHANDISE                                       Amazon Prime
# 0   FOOD_AND_BEVERAGES                                         McDonald's
# 1   FOOD_AND_BEVERAGES                                          Starbucks
# 2   FOOD_AND_BEVERAGES                                        Chick-fil-A
# 3   FOOD_AND_BEVERAGES                                          Taco Bell
# 4   FOOD_AND_BEVERAGES                                            Wendy's
# 5   FOOD_AND_BEVERAGES                                        Burger King
# 6   FOOD_AND_BEVERAGES                                     Dunkin' Donuts
# 7   FOOD_AND_BEVERAGES                                        McDonald''s
# 8   FOOD_AND_BEVERAGES                                              Sonic
# 9   FOOD_AND_BEVERAGES                             Chipotle Mexican Grill
# 0            GROCERIES                                            Walmart
# 1            GROCERIES                                             Kroger
# 2            GROCERIES                                             Target
# 3            GROCERIES                                             Publix
# 4            GROCERIES                                            Safeway
# 5            GROCERIES                                         Albertsons
# 6            GROCERIES                                          Food Lion
# 7            GROCERIES                                 365 Market 888 432
# 8            GROCERIES                                             Meijer
# 9            GROCERIES                                         Fred Meyer
# 0               TRAVEL                                               Uber
# 1               TRAVEL                                          Uber Eats
# 2               TRAVEL                                               Lyft
# 3               TRAVEL  POS Debit - Visa Check Card XXXX - UBER TRIP H...
# 4               TRAVEL                        UBER TRIP XXXXXXXXXX CA USA
# 5               TRAVEL                  Army & Air Force Exchange Service
# 6               TRAVEL  XXXXX POS SIGNATURE UBER TRIP HELP.UBER.COM CA...
# 7               TRAVEL                                Uber * Eats Pending
# 8               TRAVEL                                 Mgm*Betmgm Cr & Db
# 9               TRAVEL                                          Uber Trip
# 0                 PETS                                           PetSmart
# 1                 PETS                                          CHEWY.COM
# 2                 PETS                                  Pet Supplies Plus
# 3                 PETS                                              Petco
# 4                 PETS  CHECKCARD XXXX CHEWY.COM FL XXXXXXXXXXXXXXXXXX...
# 5                 PETS  POS Debit - Visa Check Card XXXX - CHEWY.COM X...
# 6                 PETS                                 ROVER.COM PET CARE
# 7                 PETS  CHECKCARD XXXX CHEWY.COM FL XXXXXXXXXXXXXXXXXX...
# 8                 PETS                                    PETSMART # XXXX
# 9                 PETS                          CHEWY.COM XXX-XXX-XXXX FL
# 0                 RENT                          SOUTHERN INVESTO WEB PMTS
# 1                 RENT  NEWREZ-SHELLPOIN WEB PMTS XXXXXXXXXX WEB ID: X...
# 2                 RENT  CHECKCARD XXXX GRACELAND RENTAL XXX-XXXXXXX KY...
# 3                 RENT                   Yardi Process Ma XX40 - WEB PMTS
# 4                 RENT                                Mira Flores OP Rent
# 5                 RENT  VANTAGE WEST VANTAGE WE SXXXXXXXXXX WEB ID: XX...
# 6                 RENT  Avana Cumberland DES:Rent ID:XXXXXXXXX INDN:Ch...
# 7                 RENT        Autosave Rent and Mattress Firm XXXXXXXXXXX
# 8                 RENT                                     Ada Properties
# 9                 RENT                             MEDPARK MANAGEMENT INC
#
#    Count
# 0  31725
# 1  11675
# 2  10148
# 3   7872
# 4   7394
# 5   7213
# 6   4760
# 7   4567
# 8   3270
# 9   3159
# 0  22670
# 1  12777
# 2   7933
# 3   6071
# 4   4694
# 5   4282
# 6   4265
# 7   3875
# 8   2925
# 9   2679
# 0  31619
# 1   8423
# 2   8343
# 3   7033
# 4   6071
# 5   2641
# 6   2384
# 7   2236
# 8   1838
# 9   1378
# 0   7989
# 1   5691
# 2   4648
# 3    893
# 4    781
# 5    645
# 6    509
# 7    506
# 8    364
# 9    311
# 0   1450
# 1    255
# 2    228
# 3    138
# 4    136
# 5     58
# 6     54
# 7     52
# 8     42
# 9     42
# 0     47
# 1     37
# 2     30
# 3     29
# 4     26
# 5     26
# 6     26
# 7     21
# 8     20
# 9     19
