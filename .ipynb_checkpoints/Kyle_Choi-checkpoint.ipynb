# %%
import pandas as pd
Inflows = pd.read_parquet("/uss/hdsi-prismdata/q1-ucsd-inflows.pqt")
Outflows = pd.read_parquet("/uss/hdsi-prismdata/q1-ucsd-outflows.pqt")

# %%
from sklearn.model_selection import train_test_split

# %%
Outflows['amount'] = -1 * Outflows['amount']

# %%
Outflows
# Out:
#          prism_consumer_id prism_account_id  \
# 0                        0            acc_0
# 1                        0            acc_0
# 2                        0            acc_0
# 3                        0            acc_0
# 4                        0            acc_0
# ...                    ...              ...
# 2597483               5941         acc_9524
# 2597484               5941         acc_9524
# 2597485               5941         acc_9524
# 2597486               5941         acc_9524
# 2597487               5941         acc_9524
#
#                                               memo  amount posted_date  \
# 0                                             LOAN -900.60  2022-07-05
# 1                                         ATM_CASH  -80.00  2022-03-25
# 2        TST* Casa Del Rio - Exp Fairlawn OH 09/24  -18.42  2022-09-26
# 3                                             LOAN -634.00  2023-01-10
# 4                               Buffalo Wild Wings  -26.47  2022-09-12
# ...                                            ...     ...         ...
# 2597483                                   ATM_CASH   -8.42  2023-01-25
# 2597484                                   ATM_CASH   -2.06  2023-01-25
# 2597485                                   ATM_CASH -262.88  2023-01-25
# 2597486                                   ATM_CASH  -10.00  2023-01-25
# 2597487                              UNCATEGORIZED  -35.13  2023-01-25
#
#                    category
# 0                      LOAN
# 1                  ATM_CASH
# 2        FOOD_AND_BEVERAGES
# 3                      LOAN
# 4        FOOD_AND_BEVERAGES
# ...                     ...
# 2597483            ATM_CASH
# 2597484            ATM_CASH
# 2597485            ATM_CASH
# 2597486            ATM_CASH
# 2597487       UNCATEGORIZED
#
# [2597488 rows x 6 columns]

# %%
Cash_Flows = pd.concat([Outflows, Inflows])

# %%
testing = Cash_Flows.set_index("prism_consumer_id")

# %%
train, test = train_test_split(testing, test_size=0.25)

# %%
test
# Out:
#                   prism_account_id  \
# prism_consumer_id
# 2766                      acc_6349
# 5593                      acc_9176
# 3422                      acc_7005
# 892                       acc_2572
# 1043                      acc_2949
# ...                            ...
# 4546                      acc_8129
# 1815                      acc_5024
# 1048                      acc_2965
# 854                       acc_2463
# 2115                      acc_5698
#
#                                                                 memo  amount  \
# prism_consumer_id
# 2766                                                   SELF_TRANSFER   -0.47
# 5593                                                   ENTERTAINMENT  -73.17
# 3422                                                   SELF_TRANSFER   80.00
# 892                                                         ATM_CASH  -62.00
# 1043               Withdrawal Debit Card / AZ GAME & FISH DEPT AZ...  -26.00
# ...                                                              ...     ...
# 4546                                               EXTERNAL_TRANSFER -100.00
# 1815                                                      AUTOMOTIVE -102.18
# 1048                   Debit Purchase -visa Card XXXXflat Branch Pub  -20.19
# 854                                                           Amazon  -66.60
# 2115                                               EXTERNAL_TRANSFER  165.00
#
#                   posted_date             category
# prism_consumer_id
# 2766               2022-09-04        SELF_TRANSFER
# 5593               2022-12-12        ENTERTAINMENT
# 3422               2023-02-03        SELF_TRANSFER
# 892                2021-04-29             ATM_CASH
# 1043               2021-06-08  GENERAL_MERCHANDISE
# ...                       ...                  ...
# 4546               2022-06-15    EXTERNAL_TRANSFER
# 1815               2021-09-30           AUTOMOTIVE
# 1048               2022-07-25   FOOD_AND_BEVERAGES
# 854                2021-07-30  GENERAL_MERCHANDISE
# 2115               2022-11-29    EXTERNAL_TRANSFER
#
# [777651 rows x 5 columns]
