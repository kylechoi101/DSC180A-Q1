# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from scipy.stats import ttest_ind

import re
from typing import List, Tuple, Iterable, Optional
from collections import Counter

# %% [markdown]
# # Load Data
# ## Train Test Split

# %%
inflow = pd.read_parquet('/uss/hdsi-prismdata/q1-ucsd-inflows.pqt')
outflow = pd.read_parquet('/uss/hdsi-prismdata/q1-ucsd-outflows.pqt')

# remove rows where memo = category
outflow = outflow[outflow['memo'] != outflow['category']]

outflow_ids = set(outflow["prism_consumer_id"].unique())
inflow_ids = set(inflow["prism_consumer_id"].unique())

in_not_out = inflow_ids - outflow_ids
out_not_in = outflow_ids - inflow_ids

#consumers in both inflow and outflow
consumers_both = sorted(set(inflow["prism_consumer_id"]).intersection(outflow["prism_consumer_id"]))

#80-20 train test split
train_ids, test_ids = train_test_split(consumers_both, test_size=0.2, random_state=42)

inflow_train = inflow[inflow["prism_consumer_id"].isin(train_ids)]
inflow_test  = inflow[inflow["prism_consumer_id"].isin(test_ids)]

outflow_train = outflow[outflow["prism_consumer_id"].isin(train_ids)]
outflow_test  = outflow[outflow["prism_consumer_id"].isin(test_ids)]

# print(f'Inflow_train: {inflow_train["amount"].median()}\nInflow_test: {inflow_test["amount"].median()}\nOutflow_train: {outflow_train["amount"].median()}\nOutflow_test: {outflow_test["amount"].median()}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 inflow = pd.read_parquet('q1-ucsd-inflows.pqt')
#       2 outflow = pd.read_parquet('q1-ucsd-outflows.pqt')
#       4 outflow_ids = set(outflow["prism_consumer_id"].unique())
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/parquet.py:267, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     264 if manager == "array":
#     265     to_pandas_kwargs["split_blocks"] = True  # type: ignore[assignment]
# --> 267 path_or_handle, handles, filesystem = _get_path_or_handle(
#     268     path,
#     269     filesystem,
#     270     storage_options=storage_options,
#     271     mode="rb",
#     272 )
#     273 try:
#     274     pa_table = self.api.parquet.read_table(
#     275         path_or_handle,
#     276         columns=columns,
#    (...)
#     279         **kwargs,
#     280     )
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/parquet.py:140, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     130 handles = None
#     131 if (
#     132     not fs
#     133     and not is_dir
#    (...)
#     138     # fsspec resources can also point to directories
#     139     # this branch is used for example when reading from non-fsspec URLs
# --> 140     handles = get_handle(
#     141         path_or_handle, mode, is_text=False, storage_options=storage_options
#     142     )
#     143     fs = None
#     144     path_or_handle = handles.handle
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'q1-ucsd-inflows.pqt'

# %% [markdown]
# ## Remove Observed Patterns

# %%
## use train_memos.txt to observe patterns from original outflow_train
# unique_memos = np.sort(outflow_train[outflow_train['memo']!=outflow_train['category']]['memo'].str.lower().unique())
# np.savetxt("train_memos.txt", unique_memos, fmt="%s")

# %%
m = outflow_train[outflow_train['memo']!=outflow_train['category']]['memo'].str.lower()
clean = m.copy(deep = True)

websites = re.compile(r'\b(?:www\.)?([a-wy-z0-9]+)[.\s](com|com|net|org|gov)\b', flags=re.IGNORECASE)

# extract website domain
def extract_domain(text):
    m = websites.search(text)
    if m:
        return m.group(1)
    else:
        return text

clean = clean.apply(extract_domain)

# %%
patterns = [r'^#\d*x*\s', #starting number signs with following 0 or more digits inlcuding x then space
            r'\(?(?:\d|x){3}\)?(?:\s|-)(?:\d|x){3}(?:\s|-)(?:\d|x){4}', # phone numbers in various formats
            r'(?:\s|^)[^A-Za-z0-9]?x+(?:[^A-Za-z0-9]+x+)*(?:\s|$)', #various sequences of trailing x
            r'\b[^A-Za-z0-9](al|ak|az|ar|ca|co|ct|de|fl|ga|hi|id|il|ia|ks|ky|me|md|ma|mi|mn|ms|mo|mt|ne|nv|nh|nj|nm|ny|nc|nd|oh|ok|or|pa|ri|sc|sd|tn|tx|ut|vt|va|wa|wv|wi|wy|dc)(?![A-Za-z0-9])\b',
            #state abbreviations besides 'in' bc ex: in n out
            r'\bin$', #ending 'in' state and la
            r'(?:in)?\scard\s\d{2}\s?',
            # format ex: card 20 unless in card 20
            r'\b\d{2}[/-]\d{2}(?:[/-]\d{2,4})?\b', #dates
            r'\d{2}\:\d{2}(?:\:\d{2})?[ap]?m?', #time stamps
            r'(?:date\s)?\%\%(?:\smcc)?', #format ex: %% mcc
            r'#[A-Za-z0-9]+$' #ending #_____
           ]

for p in patterns:
    clean = clean.str.replace(p, ' ', regex=True)
    clean = clean.str.replace(r'\s+', ' ', regex=True).str.strip()

changed_mask = m != clean
changed_items = m[changed_mask]
changed_count = changed_mask.sum()

print("Changed count:", changed_count)
# Out:
# Changed count: 605120

# %%
clean = clean.reindex(outflow_train.index)
outflow_train['cleaned_memo'] = clean.fillna(outflow_train['memo'])
outflow_train = outflow_train[['prism_consumer_id', 'prism_account_id', 'memo', 'cleaned_memo', 'amount', 'posted_date', 'category']]  
outflow_train[outflow_train['cleaned_memo'] != outflow_train['memo']][['memo','cleaned_memo']]
# Out:
# /tmp/ipykernel_851/730543736.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outflow_train['cleaned_memo'] = clean.fillna(outflow_train['memo'])
#                                                       memo  \
# 2                TST* Casa Del Rio - Exp Fairlawn OH 09/24
# 4                                       Buffalo Wild Wings
# 6                                          Oculus CA 04/16
# 7                              LOS GIRASOLES STOW OH 03/08
# 8                                BUZZIS LAUNDRY 1 OH 03/28
# ...                                                    ...
# 2595705   PURCHASE 01-14 PUREKANA XXX-XXXXXXX  NJ VNT XXXX
# 2595706  PURCHASE 01-18 WAL-MART #XXXX HUTCHINSON  KS S...
# 2595708  PURCHASE 01-27 CLKBANK*MoonReading XXX-XXX-XXX...
# 2595709  PURCHASE 01-26 CASH APP*DIANA STIE XXXXXXXXXX ...
# 2595710  PURCHASE 01-26 CASH APP*DIANA STIE XXXXXXXXXX ...
#
#                              cleaned_memo
# 2        tst* casa del rio - exp fairlawn
# 4                      buffalo wild wings
# 6                                  oculus
# 7                      los girasoles stow
# 8                        buzzis laundry 1
# ...                                   ...
# 2595705             purchase purekana vnt
# 2595706  purchase wal-mart hutchinson srf
# 2595708  purchase clkbank*moonreading vnt
# 2595709  purchase cash app*diana stie vnt
# 2595710  purchase cash app*diana stie vnt
#
# [1041442 rows x 2 columns]

# %% [markdown]
# ## Build n-gram

# %%
# n-gram
def tokenize(text: str, lowercase: bool = True) -> List[str]:
    if lowercase:
        text = text.lower()
    # Keep words, numbers, and apostrophes; split by comma later
    return re.findall(r"[a-z0-9']+", text)

def generate_ngrams(tokens: List[str], n: int) -> Iterable[Tuple[str, ...]]:
    """Generate n-grams of size n from tokens."""
    if n <= 0:
        raise ValueError("n must be >= 1")
    if len(tokens) < n:
        return []
    return zip(*[tokens[i:] for i in range(n)])

def most_common_ngrams(
    text: str,
    n: int = 1,
    top_k: int = 10,
    stopwords: Optional[Iterable[str]] = None,
    min_token_len: int = 1,
) -> List[Tuple[str, int]]:
    # Split the text into comma-separated segments
    segments = [seg.strip() for seg in text.split(",") if seg.strip()]

    all_tokens = []
    for seg in segments:
        tokens = tokenize(seg)
        if stopwords:
            sw = set(stopwords)
            tokens = [t for t in tokens if t not in sw]
        if min_token_len > 1:
            tokens = [t for t in tokens if len(t) >= min_token_len]
        all_tokens.append(tokens)

    # Build all n-grams up to length n within each segment
    grams = []
    for tokens in all_tokens:
        for i in range(1, n + 1):
            grams.extend(" ".join(g) for g in generate_ngrams(tokens, i))

    counts = Counter(grams)
    return counts.most_common(top_k)

# %%
# perform n-gram to find most common patterns with <= n tokens

# create corpus using all unique cleaned_memos in outflow_train
memos = outflow_train[outflow_train['memo']!=outflow_train['category']]['cleaned_memo'].unique()
memos = ', '.join(memos)
memos[:1000]
# Out:
# "tst* casa del rio - exp fairlawn, buffalo wild wings, oculus, los girasoles stow, buzzis laundry 1, tgi fridays stow, tst* the basement sp cuyahoga fall, lowe's, piada - 39, grubhub, hardees akron, market di state cuyahoga fall, swensons - montrose akron, great clips, apple, wing warehouse cuyah cuyahoga fall, winking lizard - 30, longhorn steak cuyahoga fall, on tap - cuyahoga fa cuyahoga fall, home depot, falls discount tobacc cuyahoga fls, burger king, o'charley's, homedepot, dairy queen, east of chicago - cu cuyahoga fall, giant-eag corpora uniontown, fin's bar & chill pigeon forge, acme no. 12 bai cuyahoga fall ohxxxxxx, taco bell, chick-fil-a, walmart, moe's sw grill cuyahoga fall, texas roadhouse, 39 piada cuyahoga fall, cleveland gaming fairview park, circle k, iah cnbc smartshop houston, bob evans rest stow, kohl's, moe's sw grill akron, wendy's, rays place of fairlawn fairlawn, get go st cuyahoga fall ohxxxxxx, dd doordash dashmart, chipotle mexican grill, swensons - north ak"

# %%
n_grams = most_common_ngrams(memos, n=10, top_k=50)
# longer patterns may include shorter patterns --> remove longer ones first
sorted_by_len = sorted(n_grams, key=lambda x: len(x[0]), reverse = True)
sorted_by_len[:10]
# Out:
# [('pos debit visa check card', 6856),
#  ('pxxxxxxxxxxxxxxxxx card', 4003),
#  ('purchase authorized on', 33710),
#  ('sxxxxxxxxxxxxxxx card', 26726),
#  ('debit visa check card', 6856),
#  ('pxxxxxxxxxxxxxxx card', 5666),
#  ('pos debit visa check', 6856),
#  ('purchase authorized', 33710),
#  ('debit card purchase', 6352),
#  ('pxxxxxxxxxxxxxxxxx', 4003)]

# %%
m = outflow_train[outflow_train['memo']!=outflow_train['category']]['cleaned_memo'].str.lower()
clean = m.copy(deep = True)

patterns = [r'\b(?:in)?\s[sp]xxxxxxxxxxxxxxx\scard',
            r'\b[sp]?x{3,}',
            r'(?:purchase\s)?authorized(?:\son)?',
            r'debit(?:\scard)?',
            r'visa\s(?:check\s)?card',
            r'withdrawal',
            r'recurring',
            r'checkcard',
            r'purchase',
            r'^[^A-Za-z0-9]|\-\s',
            r'\#[a-zA-Z0-9]+\s'
           ]

for p in patterns:
    clean = clean.str.replace(p, ' ', regex=True)
    clean = clean.str.replace(r'\s+', ' ', regex=True).str.strip()

changed_mask = m != clean
changed_items = m[changed_mask]
changed_count = changed_mask.sum()

print("Changed count:", changed_count)
# Out:
# Changed count: 367753

# %% [markdown]
# ### check if any other common patterns can be removed

# %%
memos = ', '.join(clean)

max_len = int(outflow_train['cleaned_memo'].str.split().str.len().max())
# find top 50 patterns with <= max_len tokens
n_grams = most_common_ngrams(memos, n=max_len, top_k=50)
# longer patterns may include shorter patterns --> remove longer ones first
sorted_by_len = sorted(n_grams, key=lambda x: len(x[0]), reverse = True)
sorted_by_len[:10]
# Out:
# [('dollar general', 10898),
#  ("mcdonald's", 29782),
#  ('starbucks', 15166),
#  ('cash app', 37056),
#  ('doordash', 22096),
#  ('7 eleven', 16599),
#  ('wal mart', 16281),
#  ('circle k', 12553),
#  ('afterpay', 10472),
#  ('point of', 10160)]

# %% [markdown]
# ## Use txt file to observe again

# %%
# np.savetxt("after_ngram_memos.txt", np.sort(clean.unique()), fmt="%s")

patterns = [r'^\d{2}\-\d{2}(?:\-\d{2,4})?\b', #leading dates
            r'c\#\sdbt\scrd', #format ex: c# dbt crd
            r'\bc\#?$', #ending c or c#
            r'\bcard#$', #ending card#
            r'\s[a-z]{0,2}x{3,}\s', #ex: fxxxx, cxxxx
           ]

for p in patterns:
    clean = clean.str.replace(p, ' ', regex=True)
    clean = clean.str.replace(r'\s+', ' ', regex=True).str.strip()

changed_mask = m != clean
changed_items = m[changed_mask]
changed_count = changed_mask.sum()

print("Changed count:", changed_count)
# Out:
# Changed count: 380312

# %%
clean = clean.reindex(outflow_train.index)
outflow_train['cleaned_memo'] = clean.fillna(outflow_train['memo'])
outflow_train = outflow_train[['prism_consumer_id', 'prism_account_id', 'memo', 'cleaned_memo', 'amount', 'posted_date', 'category']]  
outflow_train.head(5)
# Out:
#    prism_consumer_id prism_account_id  \
# 2                  0            acc_0
# 4                  0            acc_0
# 6                  0            acc_0
# 7                  0            acc_0
# 8                  0            acc_0
#
#                                         memo                    cleaned_memo  \
# 2  TST* Casa Del Rio - Exp Fairlawn OH 09/24  tst* casa del rio exp fairlawn
# 4                         Buffalo Wild Wings              buffalo wild wings
# 6                            Oculus CA 04/16                          oculus
# 7                LOS GIRASOLES STOW OH 03/08              los girasoles stow
# 8                  BUZZIS LAUNDRY 1 OH 03/28                buzzis laundry 1
#
#    amount posted_date             category
# 2   18.42  2022-09-26   FOOD_AND_BEVERAGES
# 4   26.47  2022-09-12   FOOD_AND_BEVERAGES
# 6   11.73  2022-04-18  GENERAL_MERCHANDISE
# 7   30.04  2022-03-09   FOOD_AND_BEVERAGES
# 8    4.16  2022-03-29  GENERAL_MERCHANDISE

# %%
outflow_train.sample(50).groupby(['memo','cleaned_memo'])[['amount']].count()
# Out:
#                                                                                                        amount
# memo                                               cleaned_memo
# #XXXXXX POS CASH APP*GOLD H SQUAREUP.COM SAN FR... squareup                                                 1
# AJ'S #087 CHANDLER AZ                XXXXXX  08/31 aj's chandler                                            1
# Amazon                                             amazon                                                   2
# Amazon Prime                                       amazon prime                                             1
# Annas Liquor                                       annas liquor                                             1
# Apple                                              apple                                                    1
# Audible                                            audible                                                  1
# CHECKCARD XXXX AMAZON.COM*1M0VI8J90 AM AMZN.COM... amazon                                                   1
# CHECKCARD XXXX CRYPTO.COM XXX-XXXXXXX DE XXXXXX... crypto                                                   1
# CHECKCARD XXXX LITTLE CAESARS 32 SC XXXXXXXXXXX... little caesars 32                                        1
# Coca Cola Fossil Creek                             coca cola fossil creek                                   1
# DAVIS GROCERY 03/25 #XXXXXXXXX PURCHASE DAVIS G... davis grocery davis grocery o                            1
# DBT CRD XXXX XXXXXXXX TST EDDIES IRISH PUB PRAI... dbt crd tst eddies irish pub prairie du chwi             1
# Debit Card Cleo                                    cleo                                                     1
# Debit Purchase Card XXXXozark Beverage Pinevill... card ozark beverage pineville                            1
# DoorDash                                           doordash                                                 1
# EL GRAN CANARIO II RICHMOND HILL NY          09/30 el gran canario ii richmond hill                         1
# FIVE GUYS UT XXXX QS AMERICAN FORK UT        01/21 five guys qs american fork                               1
# Food Lion                                          food lion                                                1
# GUSTO DES:NET XXXXXX ID:6semjr06pbp INDN:Newhou... gusto des:net :6semjr06pbp indn:newhouse law gr...       1
# Gallatinelectrc Payste Tngalla                     gallatinelectrc payste tngalla                           1
# Home Depot                                         home depot                                               1
# Intelius                                           intelius                                                 1
# Lowe's                                             lowe's                                                   1
# MAVERIK #466 FLAGSTAFF AZ 09/28                    maverik flagstaff                                        1
# MERCHANT PAYMENT - XXXXXX KROGER #5 XXXX SOLDAN... merchant payment kroger soldana columbus on fro...       1
# McDonald's                                         mcdonald's                                               2
# Mgm*Betmgm Cr & Db                                 mgm*betmgm cr & db                                       1
# POS Debit - Visa Check Card XXXX - IN N OUT BUR... pos in n out burger 08 san diego joshua j chilt...       1
# POS Withdrawal (FIS) 7ELEVEN / XXXX OS (ISA) 7E... pos (fis) 7eleven / os (isa) 7eleven osl gardem...       1
# PURCHASE AUTHORIZED ON 01/05 TN* SOMTUM THAI L ... somtum thai l 172-                                       1
# PURCHASE AUTHORIZED ON 02/06 QUICK CHEK FOOD FO... quick chek food fords                                    1
# PURCHASE AUTHORIZED ON 03/11 TST* GRATO FL SXXX... tst* grato                                               1
# PURCHASE AUTHORIZED ON 03/27 SAMSCLUB #XXXX PLA... samsclub plano card                                      1
# PURCHASE AUTHORIZED ON 04/02 STICKY RICE RICHMO... sticky rice richmond                                     1
# PURCHASE AUTHORIZED ON 05/18 KIKOS LIQUORS UNIO... kikos liquors union city card                            1
# PURCHASE AUTHORIZED ON 06/18 CAFE RIO XXXX SAN ... cafe rio san gilbert                                     1
# PURCHASE AUTHORIZED ON 09/09 eBay O*01-XXXXX-62... ebay o*01 -62                                            1
# PURCHASE AUTHORIZED ON 09/22 USA*VENDING MACHIN... usa*vending machin everett                               1
# PURCHASE AUTHORIZED ON 12/05 DRAGON STAR ORIENT... dragon star orient st paul                               1
# Point Of Sale Withdrawal / MCDONALD'S FXXXX 506... point of sale / mcdonald's 506 n tyler rd wichi...       1
# Pos Debit- XXXX XXXX Nawab Indian Cuisi            pos nawab indian cuisi                                   1
# Publix                                             publix                                                   1
# RECURRING PAYMENT AUTHORIZED ON 06/27 WIX*Wix.C... payment wix*wix.com, inc. ca                             1
# Recurring Debit Purchase Card XXXXapple.com/bill   card apple.com/bill                                      1
# SMITHS #XXXX XXXX E BO LAS VEGAS NV XXXXXX 09/24   smiths e bo las vegas                                    1
# UBER EATS XXXXXXXXXX CA USA                        uber eats usa                                            1
# XXXX XXXXXXXX HIBBETT SPORTS #XXXX DECORAH IA C... hibbett sports decorah                                   1

# %%
# clean_memos = np.sort(outflow_train[outflow_train['memo']!=outflow_train['category']]['cleaned_memo'].unique())
# np.savetxt("cleaned_train_memos.txt", clean_memos, fmt="%s")

# %%
outflow_train.sort_values(by='cleaned_memo')
# Out:
#         prism_consumer_id prism_account_id  \
# 763744               1617         acc_4488
# 306986                672         acc_1961
# 306988                672         acc_1961
# 307058                672         acc_1961
# 307066                672         acc_1961
# ...                   ...              ...
# 5128                   12           acc_28
# 4931                   12           acc_28
# 5089                   12           acc_28
# 5207                   12           acc_28
# 4796                   12           acc_28
#
#                                                      memo  \
# 763744                                       XXX-XXX-XXXX
# 306986                                             # XXXX
# 306988                                             # XXXX
# 307058                                             # XXXX
# 307066                                             # XXXX
# ...                                                   ...
# 5128    DEBIT CARD PURCHASE / | ON 10/03 AT TST SUNFLO...
# 4931    DEBIT CARD PURCHASE / | ON 09/15 AT TUG BOAT F...
# 5089    DEBIT CARD PURCHASE / | ON 05/15 AT VINTAGE CH...
# 5207    DEBIT CARD PURCHASE / | ON 01/06 AT WAYSIDE LU...
# 4796    DEBIT CARD PURCHASE / | ON 04/12 AT WENDY S TR...
#
#                                         cleaned_memo  amount posted_date  \
# 763744                                                633.42  2021-09-17
# 306986                                                150.00  2022-01-19
# 306988                                                250.00  2022-05-26
# 307058                                                 33.00  2022-03-18
# 307066                                                 10.00  2022-05-27
# ...                                              ...     ...         ...
# 5128     | on at tst sunflower drive in| fair oaks |   35.59  2020-10-05
# 4931    | on at tug boat fish n chips 2| fair oaks |   45.75  2021-09-17
# 5089        | on at vintage charm antiques| loomis |  158.02  2021-05-17
# 5207                   | on at wayside lumber inc| |  262.18  2021-01-07
# 4796         | on at wendy s trade ce| rancho cordov    3.45  2021-04-12
#
#                    category
# 763744   FOOD_AND_BEVERAGES
# 306986   FOOD_AND_BEVERAGES
# 306988   FOOD_AND_BEVERAGES
# 307058   FOOD_AND_BEVERAGES
# 307066   FOOD_AND_BEVERAGES
# ...                     ...
# 5128     FOOD_AND_BEVERAGES
# 4931     FOOD_AND_BEVERAGES
# 5089    GENERAL_MERCHANDISE
# 5207    GENERAL_MERCHANDISE
# 4796     FOOD_AND_BEVERAGES
#
# [1041668 rows x 7 columns]

# %%
outflow_train.loc[307802]
# Out:
# prism_consumer_id                   672
# prism_account_id               acc_1961
# memo                             # XXXX
# cleaned_memo
# amount                            150.0
# posted_date                  2022-04-28
# category             FOOD_AND_BEVERAGES
# Name: 307802, dtype: object

# %% [markdown]
# ## Questions

# %% [markdown]
# ### 1. Many empty memos --> how to categorize?

# %%
empty_memo = outflow_train[outflow_train['cleaned_memo'] == '']
empty_memo
# Out:
#          prism_consumer_id prism_account_id  \
# 36942                   79          acc_225
# 109807                 241          acc_722
# 109874                 241          acc_722
# 109903                 241          acc_722
# 124326                 283          acc_866
# ...                    ...              ...
# 1846481               4531         acc_8114
# 1846492               4531         acc_8114
# 1876720               4595         acc_8178
# 2385209               5543         acc_9126
# 2487445               5761         acc_9344
#
#                                            memo cleaned_memo   amount  \
# 36942                                         *                 42.80
# 109807   Debit Card Purchase 05/09 08:04p #XXXX               2500.00
# 109874   Debit Card Purchase 01/11 12:03p #XXXX               1000.00
# 109903   Debit Card Purchase 12/12 03:10p #XXXX                500.00
# 124326                           #BREEDOESHAIR9                 30.00
# ...                                         ...          ...      ...
# 1846481                         XXXXXXXXXXXXXXX                  1.60
# 1846492                         XXXXXXXXXXXXXXX                  1.60
# 1876720                                   XXXXX                 41.11
# 2385209                      XXXXXXXXXXX XXXXXX               1283.65
# 2487445                                XXXXXXXX                 69.99
#
#         posted_date             category
# 36942    2021-05-05   FOOD_AND_BEVERAGES
# 109807   2023-05-11   FOOD_AND_BEVERAGES
# 109874   2023-01-13  GENERAL_MERCHANDISE
# 109903   2022-12-14   FOOD_AND_BEVERAGES
# 124326   2020-12-17   FOOD_AND_BEVERAGES
# ...             ...                  ...
# 1846481  2022-10-07   FOOD_AND_BEVERAGES
# 1846492  2022-10-09   FOOD_AND_BEVERAGES
# 1876720  2022-11-25   FOOD_AND_BEVERAGES
# 2385209  2022-05-31   FOOD_AND_BEVERAGES
# 2487445  2022-05-04   FOOD_AND_BEVERAGES
#
# [188 rows x 7 columns]

# %%
empty_memo['category'].unique()
# Out:
# array(['FOOD_AND_BEVERAGES', 'GENERAL_MERCHANDISE'], dtype=object)

# %%
empty_memo['memo'].unique()
# Out:
# array(['*', 'Debit Card Purchase 05/09 08:04p #XXXX',
#        'Debit Card Purchase 01/11 12:03p #XXXX',
#        'Debit Card Purchase 12/12 03:10p #XXXX', '#BREEDOESHAIR9',
#        'XXXXXXXX', 'XXXXXXXXXX',
#        'PURCHASE AUTHORIZED ON 09/21 CT CT SXXXXXXXXXXXXXXX CARD XXXX',
#        '# XXXX', 'CHECKCARD XXXX XXXXXXXXXXXXXX',
#        'Debit Card Purchase 03/03 01:59p #XXXX',
#        'Debit Card Purchase 08/31 03:35p #XXXX',
#        'Debit Card Purchase 12/22 03:10p #XXXX',
#        'Debit Card Purchase 11/09 12:07p #XXXX',
#        'Debit Card Purchase 12/29 08:00p #XXXX',
#        'Debit Card Purchase 03/19 02:16p #XXXX',
#        'Debit Card Purchase 02/07 03:59p #XXXX',
#        'Debit Card Purchase 09/05 01:01p #XXXX',
#        'Debit Card Purchase 05/09 02:16p #XXXX',
#        'Debit Card Purchase 09/16 07:59p #XXXX',
#        'Debit Card Purchase 03/17 03:25p #XXXX',
#        'Debit Card Purchase 09/19 03:00p #XXXX',
#        'Debit Card Purchase 12/17 12:25a #XXXX',
#        'Debit Card Purchase 09/20 03:16p #XXXX',
#        'Debit Card Purchase 04/12 02:16p #XXXX',
#        'Debit Card Purchase 05/13 12:04p #XXXX',
#        'Debit Card Purchase 09/08 03:08p #XXXX',
#        'Debit Card Purchase 04/28 03:16p #XXXX',
#        'Debit Card Purchase 11/10 09:16p #XXXX',
#        'Debit Card Purchase 07/12 03:08p #XXXX',
#        'Debit Card Purchase 05/26 03:00p #XXXX', 'XXXXXXXXXXXXX',
#        'Debit Card Purchase 07/02 05:42p #XXXX',
#        'Debit Card Purchase 02/28 01:25p #XXXX',
#        'Debit Card Purchase 08/03 12:42p #XXXX',
#        'Debit Card Purchase 10/28 08:10p #XXXX',
#        'Debit Card Purchase 08/09 08:36p #XXXX',
#        'Debit Card Purchase 01/06 12:35p #XXXX',
#        'Debit Card Purchase 07/06 08:47p #XXXX',
#        'Debit Card Purchase 08/15 02:01p #XXXX',
#        'Debit Card Purchase 08/11 05:10p #XXXX',
#        'Debit Card Purchase 07/06 03:10p #XXXX',
#        'Debit Card Purchase 01/02 02:01p #XXXX',
#        'Debit Card Purchase 05/28 12:07a #XXXX',
#        'Debit Card Purchase 08/19 05:42p #XXXX',
#        'Debit Card Purchase 09/10 12:37p #XXXX',
#        'Debit Card Purchase 03/13 05:42p #XXXX',
#        'Debit Card Purchase 07/11 05:42p #XXXX',
#        'Debit Card Purchase 10/23 09:08p #XXXX',
#        'Debit Card Purchase 04/08 07:27p #XXXX',
#        'Debit Card Purchase 10/17 03:10p #XXXX',
#        'Debit Card Purchase 12/31 01:36a #XXXX',
#        'Debit Card Purchase 03/08 03:05p #XXXX',
#        'Debit Card Purchase 04/26 07:59p #XXXX',
#        'Debit Card Purchase 03/26 12:59p #XXXX',
#        'Debit Card Purchase 05/24 02:59p #XXXX',
#        'Debit Card Purchase 07/28 08:03p #XXXX',
#        'Debit Card Purchase 09/23 02:25p #XXXX',
#        'PURCHASE AUTHORIZED ON 11/04 XXXXXXXXXXX NY SXXXXXXXXXXXXXXX CARD XXXX',
#        '#3', 'XXXX', 'CHECKCARD XXXX XXXXXXXXXXXX', 'XXX-XXX-XXXX',
#        'XXXXXXXXX', 'X. XXXXXXXXXXX', 'XXXXXXX', 'XXXXXXXXXXXX',
#        'Debit Card Purchase 10/01 08:43p #XXXX',
#        'Debit Card Purchase 10/02 01:16p #XXXX',
#        'Debit Card Purchase 10/10 08:43p #XXXX',
#        'Debit Card Purchase 11/03 12:07p #XXXX',
#        'Debit Card Purchase 11/19 08:37p #XXXX',
#        'Debit Card Purchase 11/26 08:25a #XXXX',
#        'Debit Card Purchase 02/11 08:00p #XXXX',
#        'Debit Card Purchase 02/26 07:01p #XXXX',
#        'Debit Card Purchase 03/09 03:07a #XXXX',
#        'Debit Card Purchase 03/11 03:36a #XXXX',
#        'Debit Card Purchase 03/11 08:00p #XXXX',
#        'Debit Card Purchase 04/18 06:59p #XXXX',
#        'Debit Card Purchase 04/23 03:05p #XXXX',
#        'Debit Card Purchase 04/23 07:08p #XXXX',
#        'Debit Card Purchase 04/29 06:50p #XXXX',
#        'Debit Card Purchase 05/19 12:23a #XXXX',
#        'Debit Card Purchase 05/31 08:43p #XXXX',
#        'Debit Card Purchase 06/24 09:07a #XXXX',
#        'Debit Card Purchase 07/09 07:16p #XXXX',
#        'Debit Card Purchase 08/30 08:14p #XXXX',
#        'Debit Card Purchase 08/31 03:37p #XXXX',
#        'Debit Card Purchase 09/01 12:49a #XXXX',
#        'Debit Card Purchase 09/04 03:04p #XXXX', 'XXXXXXXXXXXXXXX',
#        'XXXXX', 'XXXXXXXXXXX XXXXXX'], dtype=object)
