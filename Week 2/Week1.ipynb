# %%
import pandas as pd
Inflows = pd.read_parquet("/uss/hdsi-prismdata/q1-ucsd-inflows.pqt")
Outflows = pd.read_parquet("/uss/hdsi-prismdata/q1-ucsd-outflows.pqt")

# %%
Inflows
# Out:
#         prism_consumer_id prism_account_id               memo   amount  \
# 0                       0            acc_0           PAYCHECK  2477.02
# 1                       0            acc_0  EXTERNAL_TRANSFER   100.00
# 2                       0            acc_0      MISCELLANEOUS     6.29
# 3                       0            acc_0  EXTERNAL_TRANSFER   277.00
# 4                       0            acc_0  EXTERNAL_TRANSFER   100.00
# ...                   ...              ...                ...      ...
# 513110               5941         acc_9524  EXTERNAL_TRANSFER     8.66
# 513111               5941         acc_9524  EXTERNAL_TRANSFER   267.13
# 513112               5941         acc_9524  EXTERNAL_TRANSFER     2.00
# 513113               5941         acc_9524  EXTERNAL_TRANSFER   207.16
# 513114               5941         acc_9524  EXTERNAL_TRANSFER   281.71
#
#        posted_date           category
# 0       2022-03-18           PAYCHECK
# ...

# %%
Outflows
# Out:
#          prism_consumer_id prism_account_id  \
# 0                        0            acc_0
# 1                        0            acc_0
# 2                        0            acc_0
# 3                        0            acc_0
# 4                        0            acc_0
# ...                    ...              ...
# 2597483               5941         acc_9524
# 2597484               5941         acc_9524
# 2597485               5941         acc_9524
# 2597486               5941         acc_9524
# 2597487               5941         acc_9524
#
#                                               memo  amount posted_date  \
# 0                                             LOAN  900.60  2022-07-05
# 1                                         ATM_CASH   80.00  2022-03-25
# 2        TST* Casa Del Rio - Exp Fairlawn OH 09/24   18.42  2022-09-26
# 3                                             LOAN  634.00  2023-01-10
# 4                               Buffalo Wild Wings   26.47  2022-09-12
# ...

# %%
Outflows.groupby("prism_consumer_id").apply(lambda x: x)
# Out:
# /tmp/ipykernel_290/747692145.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   Outflows.groupby("prism_consumer_id").apply(lambda x: x)
#                            prism_consumer_id prism_account_id  \
# prism_consumer_id
# 0                 0                        0            acc_0
#                   1                        0            acc_0
#                   2                        0            acc_0
#                   3                        0            acc_0
#                   4                        0            acc_0
# ...                                      ...              ...
# 5941              2597484               5941         acc_9524
# ...

# %%
most_common = Outflows["category"].value_counts()
most_common.reset_index()
# Out:
#                category   count
# 0   GENERAL_MERCHANDISE  524063
# 1    FOOD_AND_BEVERAGES  481994
# 2     EXTERNAL_TRANSFER  320998
# 3             GROCERIES  219331
# 4            AUTOMOTIVE  208579
# 5              ATM_CASH  117651
# 6         UNCATEGORIZED  117409
# 7                  LOAN   90945
# 8         ENTERTAINMENT   80885
# 9    ESSENTIAL_SERVICES   77137
# 10  CREDIT_CARD_PAYMENT   75506
# 11        SELF_TRANSFER   73281
# 12               TRAVEL   59647
# 13   HEALTHCARE_MEDICAL   40842
# 14         ACCOUNT_FEES   37511
# 15            INSURANCE   30244
# 16                 PETS    9266
# 17     HOME_IMPROVEMENT    8600
# 18      GIFTS_DONATIONS    4719
# 19            EDUCATION    4499
# 20            OVERDRAFT    3386
# 21                  TAX    3186
# 22                 RENT    3147
# 23                 BNPL    1543
# 24             MORTGAGE    1119
# 25             PAYCHECK    1040
# 26     CHILD_DEPENDENTS     936
# 27      BILLS_UTILITIES      23
# ...

# %%
six_unique = ["GENERAL_MERCHANDISE", "FOOD_AND_BEVERAGES", "GROCERIES", "TRAVEL", "PETS", "EDUCATION"]

# %%
for i in six_unique:
    memos = ""
    this_cat = Outflows[Outflows["category"] == i]
    print(i, this_cat["memo"])
# Out:
# GENERAL_MERCHANDISE 6                                            Oculus CA 04/16
# 8                                  BUZZIS LAUNDRY 1 OH 03/28
# 9                                  BUZZIS LAUNDRY 1 OH 02/13
# 13                                                    Lowe's
# 20                                               Great Clips
#                                  ...
# 2597370    POS WITHDRAWALWALGREENS STORE XXXX W PE GLENDA...
# 2597387    POS WITHDRAWALARCO #XXXXX AMPM XXXXX N 19TH US...
# 2597415    DEBIT CARD WITHDRAWAL PURCHASEAMZN Mktp US*SP6...
# 2597428    DEBIT CARD WITHDRAWAL PURCHASEAudible*Z295DXXX...
# 2597457    DEBIT CARD WITHDRAWAL PURCHASEAmazon Prime*TI4...
# Name: memo, Length: 524063, dtype: object
# FOOD_AND_BEVERAGES 2                  TST* Casa Del Rio - Exp Fairlawn OH 09/24
# 4                                         Buffalo Wild Wings
# 7                                LOS GIRASOLES STOW OH 03/08
# ...
